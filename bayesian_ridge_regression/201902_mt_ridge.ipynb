# %%
import pandas as pd
import pymc3 as pm
import altair as alt
import numpy as np

# %% [markdown]
# ridge regression on high dimensional dataset
#
# load & visualize data
# run regression unsing pymc3
# posterior predictive check

# %%
types = {'ID' : 'category', 'EINWOHNERKLASSE_WOHNORT' : 'category', 'KUNDENALTER' : int, 'ANZ_CS_KONTAKTE' : int,
       'ANZ_KINDER' : int, 'KINDER_GEB_SAISON' : 'category', 'ANZ_AUFTRAEGE' : int,
       'ANZ_AUFTRAEGE_0_TO_30' : int, 'ANZ_AUFTRAEGE_30_TO_90' : int,
       'ANZ_AUFTRAEGE_90_TO_180' : int, 'ANZ_AUFTRAEGE_180_TO_360' : int,
       'ANZ_AUFTRAEGE_360_TO_720' : int, 'ANZ_RETOUREN' : int, 'ANZ_RETOUREN_0_TO_30' : int,
       'ANZ_RETOUREN_30_TO_90' : int, 'ANZ_RETOUREN_90_TO_180' : int,
       'ANZ_RETOUREN_180_TO_360' : int, 'ANZ_RETOUREN_360_TO_720' : int,
       'SUM_LIEFERMENGE_AUFTRAEGE' : float, 'SUM_LIEFERMENGE_RETOUREN' : float,
       'ANZ_POSITIONEN_AUFTRAG' : int, 'ANZ_POSITIONEN_RETOUREN' : int,
       'ANZ_AUFTRAEGE_GSCHEIN' : int, 'SUM_RABATT_GSCHEIN'  : float, 'ANZ_AUFTRAEGE_NL' : int,
       'ANZ_NL_ERHALTEN_0_TO_30' : int, 'ANZ_NL_GEOEFFNET_0_TO_30' : int,
       'ANZ_AUFTRAEGE_NL_0_TO_30' : int, 'TAGE_ERSTKAUF' : int, 'TAGE_LETZTKAUF' : int,
       'TAGE_ERST_ZWEIT_KAUF' : int, 'TAGE_LETZT_VORLETZT_KAUF' : int, 'KAUF_NACH_FLYER' : 'category'}

data = pd.read_csv('20140415_Scoring_Modell_daten.csv', sep = ';', dtype = types, decimal = ',')

# %%
data.head()
# Out:
#   ID EINWOHNERKLASSE_WOHNORT  KUNDENALTER  ANZ_CS_KONTAKTE  ANZ_KINDER  \
# 0  1                     100           37                3           0
# 1  2                     100           37                1           3
# 2  3                     100           37                0           3
# 3  4                     100           41                0           2
# 4  5                     100           51                6           2
#
#   KINDER_GEB_SAISON  ANZ_AUFTRAEGE  ANZ_AUFTRAEGE_0_TO_30  \
# 0                 0             15                      0
# 1                 1             32                      2
# 2                 1             36                      0
# 3                 0             50                      0
# 4                 0              8                      1
#
#    ANZ_AUFTRAEGE_30_TO_90  ANZ_AUFTRAEGE_90_TO_180  ...  SUM_RABATT_GSCHEIN  \
# 0                       0                        1  ...               58.85
# 1                       0                        0  ...               25.00
# 2                       0                        0  ...               43.57
# 3                       0                        0  ...               22.95
# 4                       1                        1  ...                5.00
#
#    ANZ_AUFTRAEGE_NL  ANZ_NL_ERHALTEN_0_TO_30  ANZ_NL_GEOEFFNET_0_TO_30  \
# 0                 1                       10                         0
# 1                 0                        2                         0
# 2                 2                       10                         0
# 3                 0                       11                         0
# 4                 0                        3                         0
#
#    ANZ_AUFTRAEGE_NL_0_TO_30  TAGE_ERSTKAUF  TAGE_LETZTKAUF  \
# 0                         0           4734             135
# 1                         0           4660              17
# 2                         0           4896             288
# 3                         0           4580             209
# 4                         0           4557              18
#
#    TAGE_ERST_ZWEIT_KAUF  TAGE_LETZT_VORLETZT_KAUF  KAUF_NACH_FLYER
# 0                   747                       149                0
# 1                     4                         6                0
# 2                   165                       126                0
# 3                   413                       136                0
# 4                  4287                        21                0
#
# [5 rows x 33 columns]

# %%
data.describe()
# Out:
#         KUNDENALTER  ANZ_CS_KONTAKTE    ANZ_KINDER  ANZ_AUFTRAEGE  \
# count  10000.000000     10000.000000  10000.000000   10000.000000
# mean      37.607900         0.620400      0.477800      14.750100
# std        7.824186         1.471775      0.912354      18.207718
# min       16.000000         0.000000      0.000000       1.000000
# 25%       32.000000         0.000000      0.000000       4.000000
# 50%       37.000000         0.000000      0.000000       9.000000
# 75%       42.000000         1.000000      1.000000      19.000000
# max       60.000000        29.000000      9.000000     459.000000
#
#        ANZ_AUFTRAEGE_0_TO_30  ANZ_AUFTRAEGE_30_TO_90  ANZ_AUFTRAEGE_90_TO_180  \
# count           10000.000000            10000.000000             10000.000000
# mean                0.600000                0.739300                 0.916900
# std                 0.862366                1.088877                 1.437637
# min                 0.000000                0.000000                 0.000000
# 25%                 0.000000                0.000000                 0.000000
# 50%                 0.000000                0.000000                 1.000000
# 75%                 1.000000                1.000000                 1.000000
# max                13.000000               23.000000                48.000000
#
#        ANZ_AUFTRAEGE_180_TO_360  ANZ_AUFTRAEGE_360_TO_720  ANZ_RETOUREN  ...  \
# count              10000.000000              10000.000000  10000.000000  ...
# mean                   2.332400                  3.393400      5.313100  ...
# std                    2.588393                  4.690931     11.543214  ...
# min                    0.000000                  0.000000      0.000000  ...
# 25%                    1.000000                  0.000000      0.000000  ...
# 50%                    2.000000                  2.000000      2.000000  ...
# 75%                    3.000000                  5.000000      5.000000  ...
# max                   55.000000                134.000000    321.000000  ...
#
#        ANZ_AUFTRAEGE_GSCHEIN  SUM_RABATT_GSCHEIN  ANZ_AUFTRAEGE_NL  \
# count           10000.000000        10000.000000      10000.000000
# mean                1.614100           12.248203          1.615300
# std                 2.286767           19.385119          3.955562
# min                 0.000000            0.000000          0.000000
# 25%                 0.000000            0.000000          0.000000
# 50%                 1.000000           10.000000          0.000000
# 75%                 2.000000           15.000000          2.000000
# max                45.000000          464.560000        104.000000
#
#        ANZ_NL_ERHALTEN_0_TO_30  ANZ_NL_GEOEFFNET_0_TO_30  \
# count             10000.000000              10000.000000
# mean                  6.190500                  1.244800
# std                   5.182441                  2.165212
# min                   0.000000                  0.000000
# 25%                   1.000000                  0.000000
# 50%                   8.000000                  0.000000
# 75%                  10.000000                  2.000000
# max                 125.000000                 20.000000
#
#        ANZ_AUFTRAEGE_NL_0_TO_30  TAGE_ERSTKAUF  TAGE_LETZTKAUF  \
# count              10000.000000   10000.000000    10000.000000
# mean                   0.058200    1264.728200       87.235600
# std                    0.274628    1003.886037      107.863801
# min                    0.000000       2.000000        1.000000
# 25%                    0.000000     363.000000       13.000000
# 50%                    0.000000    1090.000000       41.000000
# 75%                    0.000000    1891.000000      118.000000
# max                   10.000000    5109.000000      683.000000
#
#        TAGE_ERST_ZWEIT_KAUF  TAGE_LETZT_VORLETZT_KAUF
# count          10000.000000              10000.000000
# mean             225.914300                 93.067800
# std              402.576152                152.268505
# min                0.000000                  0.000000
# 25%               17.000000                 11.000000
# 50%               81.000000                 46.000000
# 75%              269.000000                118.000000
# max             4696.000000               3079.000000
#
# [8 rows x 29 columns]

# %%
pd.isnull(data).any()
# Out:
# ID                           False
# EINWOHNERKLASSE_WOHNORT      False
# KUNDENALTER                  False
# ANZ_CS_KONTAKTE              False
# ANZ_KINDER                   False
# KINDER_GEB_SAISON            False
# ANZ_AUFTRAEGE                False
# ANZ_AUFTRAEGE_0_TO_30        False
# ANZ_AUFTRAEGE_30_TO_90       False
# ANZ_AUFTRAEGE_90_TO_180      False
# ANZ_AUFTRAEGE_180_TO_360     False
# ANZ_AUFTRAEGE_360_TO_720     False
# ANZ_RETOUREN                 False
# ANZ_RETOUREN_0_TO_30         False
# ANZ_RETOUREN_30_TO_90        False
# ANZ_RETOUREN_90_TO_180       False
# ANZ_RETOUREN_180_TO_360      False
# ANZ_RETOUREN_360_TO_720      False
# SUM_LIEFERMENGE_AUFTRAEGE    False
# SUM_LIEFERMENGE_RETOUREN     False
# ANZ_POSITIONEN_AUFTRAG       False
# ANZ_POSITIONEN_RETOUREN      False
# ANZ_AUFTRAEGE_GSCHEIN        False
# SUM_RABATT_GSCHEIN           False
# ANZ_AUFTRAEGE_NL             False
# ANZ_NL_ERHALTEN_0_TO_30      False
# ANZ_NL_GEOEFFNET_0_TO_30     False
# ANZ_AUFTRAEGE_NL_0_TO_30     False
# TAGE_ERSTKAUF                False
# TAGE_LETZTKAUF               False
# TAGE_ERST_ZWEIT_KAUF         False
# TAGE_LETZT_VORLETZT_KAUF     False
# KAUF_NACH_FLYER              False
# dtype: bool

# %% [markdown]
# histograms of numeric data

# %%
dt = data.select_dtypes(include=['int', 'float'])
dt['ID'] = data['ID']
dt.head()
# Out:
# /home/vinzent/miniconda3/envs/dataenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    KUNDENALTER  ANZ_CS_KONTAKTE  ANZ_KINDER  ANZ_AUFTRAEGE  \
# 0           37                3           0             15
# 1           37                1           3             32
# 2           37                0           3             36
# 3           41                0           2             50
# 4           51                6           2              8
#
#    ANZ_AUFTRAEGE_0_TO_30  ANZ_AUFTRAEGE_30_TO_90  ANZ_AUFTRAEGE_90_TO_180  \
# 0                      0                       0                        1
# 1                      2                       0                        0
# 2                      0                       0                        0
# 3                      0                       0                        0
# 4                      1                       1                        1
#
#    ANZ_AUFTRAEGE_180_TO_360  ANZ_AUFTRAEGE_360_TO_720  ANZ_RETOUREN  ...  \
# 0                         1                         1             3  ...
# 1                         2                         3             6  ...
# 2                         1                         2             5  ...
# 3                         2                         4            10  ...
# 4                         4                         0             0  ...
#
#    SUM_RABATT_GSCHEIN  ANZ_AUFTRAEGE_NL  ANZ_NL_ERHALTEN_0_TO_30  \
# 0               58.85                 1                       10
# 1               25.00                 0                        2
# 2               43.57                 2                       10
# 3               22.95                 0                       11
# 4                5.00                 0                        3
#
#    ANZ_NL_GEOEFFNET_0_TO_30  ANZ_AUFTRAEGE_NL_0_TO_30  TAGE_ERSTKAUF  \
# 0                         0                         0           4734
# 1                         0                         0           4660
# 2                         0                         0           4896
# 3                         0                         0           4580
# 4                         0                         0           4557
#
#    TAGE_LETZTKAUF  TAGE_ERST_ZWEIT_KAUF  TAGE_LETZT_VORLETZT_KAUF  ID
# 0             135                   747                       149   1
# 1              17                     4                         6   2
# 2             288                   165                       126   3
# 3             209                   413                       136   4
# 4              18                  4287                        21   5
#
# [5 rows x 30 columns]

# %%
plot_data = pd.melt(dt, id_vars = 'ID', value_vars = dt.columns[:28])
plot_data.head()
# Out:
#   ID     variable  value
# 0  1  KUNDENALTER   37.0
# 1  2  KUNDENALTER   37.0
# 2  3  KUNDENALTER   37.0
# 3  4  KUNDENALTER   41.0
# 4  5  KUNDENALTER   51.0

# %% [markdown]
# with standardized data

# %%
nums = data.select_dtypes(include=['int', 'float']).columns
data[nums] = data[nums].apply(lambda x : (x - np.mean(x)) / x.std(), axis=0)

# %% [markdown]
# binning isn't perfect, but shows some skewed variables

# %%
alt.data_transformers.enable('json')
alt.Chart(plot_data).mark_bar().encode(alt.X('value:Q', bin = alt.Bin(maxbins=100)), y = 'count()').facet(row = 'variable').resolve_scale(x = 'independent')
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# scatterplot matrix of some variables:
# many correlalested variab

# %%
alt.Chart(dt).mark_circle().encode( alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative')).properties(width=150, height=150).repeat(
    row = ['ANZ_AUFTRAEGE', 'ANZ_RETOUREN', 'ANZ_POSITIONEN_AUFTRAG', 'ANZ_AUFTRAEGE_NL'], column = ['ANZ_AUFTRAEGE_NL', 'ANZ_POSITIONEN_AUFTRAG', 'ANZ_RETOUREN', 'ANZ_AUFTRAEGE'])
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# train / test split

# %%
train = data.sample(frac = 2/3, random_state = 123)
test = data.drop(train.index)

# %% [markdown]
# OLS

# %%
with pm.Model() as model_1:
    # default priors: normally distributed, mimics ridge regression
    pm.glm.GLM.from_formula('KAUF_NACH_FLYER ~ EINWOHNERKLASSE_WOHNORT + KUNDENALTER + ANZ_CS_KONTAKTE + ANZ_KINDER + ANZ_AUFTRAEGE + ANZ_AUFTRAEGE_0_TO_30 + ANZ_AUFTRAEGE_30_TO_90 + \
                            ANZ_AUFTRAEGE_90_TO_180 + ANZ_AUFTRAEGE_180_TO_360 + ANZ_AUFTRAEGE_360_TO_720 + ANZ_RETOUREN + ANZ_RETOUREN_0_TO_30 + ANZ_RETOUREN_30_TO_90 + \
                            ANZ_RETOUREN_90_TO_180 + ANZ_RETOUREN_180_TO_360 + ANZ_RETOUREN_360_TO_720 + SUM_LIEFERMENGE_AUFTRAEGE + SUM_LIEFERMENGE_RETOUREN + ANZ_POSITIONEN_AUFTRAG + \
                            ANZ_POSITIONEN_RETOUREN + ANZ_AUFTRAEGE_GSCHEIN + SUM_RABATT_GSCHEIN + ANZ_AUFTRAEGE_NL + ANZ_NL_ERHALTEN_0_TO_30 + ANZ_NL_GEOEFFNET_0_TO_30 + \
                            ANZ_AUFTRAEGE_NL_0_TO_30 + TAGE_ERSTKAUF + TAGE_LETZTKAUF + TAGE_ERST_ZWEIT_KAUF + TAGE_LETZT_VORLETZT_KAUF', train, family=pm.glm.families.Binomial())
    
    #start_MAP = pm.find_MAP(fmin=optimize.fmin_powell)
    
    ## Sample using NUTS
    trace_1 = pm.sample(6000, step=pm.NUTS())
# Out:
# Sequential sampling (2 chains in 1 job)
# NUTS: [TAGE_LETZT_VORLETZT_KAUF, TAGE_ERST_ZWEIT_KAUF, TAGE_LETZTKAUF, TAGE_ERSTKAUF, ANZ_AUFTRAEGE_NL_0_TO_30, ANZ_NL_GEOEFFNET_0_TO_30, ANZ_NL_ERHALTEN_0_TO_30, ANZ_AUFTRAEGE_NL, SUM_RABATT_GSCHEIN, ANZ_AUFTRAEGE_GSCHEIN, ANZ_POSITIONEN_RETOUREN, ANZ_POSITIONEN_AUFTRAG, SUM_LIEFERMENGE_RETOUREN, SUM_LIEFERMENGE_AUFTRAEGE, ANZ_RETOUREN_360_TO_720, ANZ_RETOUREN_180_TO_360, ANZ_RETOUREN_90_TO_180, ANZ_RETOUREN_30_TO_90, ANZ_RETOUREN_0_TO_30, ANZ_RETOUREN, ANZ_AUFTRAEGE_360_TO_720, ANZ_AUFTRAEGE_180_TO_360, ANZ_AUFTRAEGE_90_TO_180, ANZ_AUFTRAEGE_30_TO_90, ANZ_AUFTRAEGE_0_TO_30, ANZ_AUFTRAEGE, ANZ_KINDER, ANZ_CS_KONTAKTE, KUNDENALTER, EINWOHNERKLASSE_WOHNORT[T.500], EINWOHNERKLASSE_WOHNORT[T.250], EINWOHNERKLASSE_WOHNORT[T.2000], EINWOHNERKLASSE_WOHNORT[T.1000], Intercept]
# 100%|██████████| 6500/6500 [42:30<00:00,  2.94it/s]
# 100%|██████████| 6500/6500 [38:14<00:00,  2.82it/s]

# %%
pm.summary(trace_1[2000: ])
# Out:
#                                      mean        sd      mc_error   hpd_2.5  \
# Intercept                       -2.671061  0.253192  2.972537e-03 -3.163377
# EINWOHNERKLASSE_WOHNORT[T.1000] -0.449873  0.273419  2.411488e-03 -1.001569
# EINWOHNERKLASSE_WOHNORT[T.2000] -0.111284  0.203106  1.867972e-03 -0.512859
# EINWOHNERKLASSE_WOHNORT[T.250]  -0.256376  0.229960  1.956740e-03 -0.701840
# EINWOHNERKLASSE_WOHNORT[T.500]  -0.289396  0.187443  1.629357e-03 -0.662503
# KUNDENALTER                     -0.004645  0.006110  7.182180e-05 -0.016305
# ANZ_CS_KONTAKTE                 -0.036074  0.027545  2.427640e-04 -0.089722
# ANZ_KINDER                      -0.097879  0.051581  5.209271e-04 -0.195352
# ANZ_AUFTRAEGE                   -0.021736  0.009373  1.416015e-04 -0.040007
# ANZ_AUFTRAEGE_0_TO_30            0.154112  0.059758  7.515538e-04  0.040076
# ANZ_AUFTRAEGE_30_TO_90           0.167602  0.051223  6.195010e-04  0.068222
# ANZ_AUFTRAEGE_90_TO_180          0.145459  0.042907  4.302111e-04  0.064766
# ANZ_AUFTRAEGE_180_TO_360         0.096296  0.026666  2.977436e-04  0.042594
# ANZ_AUFTRAEGE_360_TO_720         0.053431  0.020762  2.618468e-04  0.012150
# ANZ_RETOUREN                     0.009673  0.015459  2.080661e-04 -0.020502
# ANZ_RETOUREN_0_TO_30            -0.067400  0.080354  8.519796e-04 -0.223831
# ANZ_RETOUREN_30_TO_90            0.020712  0.070581  7.569754e-04 -0.111103
# ANZ_RETOUREN_90_TO_180          -0.017426  0.061151  6.217579e-04 -0.138546
# ANZ_RETOUREN_180_TO_360          0.065450  0.038664  4.494214e-04 -0.008309
# ANZ_RETOUREN_360_TO_720         -0.008516  0.032840  4.034839e-04 -0.072650
# SUM_LIEFERMENGE_AUFTRAEGE        0.001375  0.002940  3.198653e-05 -0.004542
# SUM_LIEFERMENGE_RETOUREN         0.036852  0.032431  3.642774e-04 -0.024766
# ANZ_POSITIONEN_AUFTRAG           0.001454  0.003284  3.644275e-05 -0.004777
# ANZ_POSITIONEN_RETOUREN         -0.041737  0.032721  3.719238e-04 -0.102799
# ANZ_AUFTRAEGE_GSCHEIN           -0.014184  0.044455  4.956548e-04 -0.103333
# SUM_RABATT_GSCHEIN               0.002293  0.005360  5.910110e-05 -0.008350
# ANZ_AUFTRAEGE_NL                 0.020379  0.010505  9.672213e-05  0.000489
# ANZ_NL_ERHALTEN_0_TO_30         -0.003642  0.009198  8.799314e-05 -0.021988
# ANZ_NL_GEOEFFNET_0_TO_30         0.055053  0.020891  2.160784e-04  0.014202
# ANZ_AUFTRAEGE_NL_0_TO_30         0.217471  0.144616  1.433664e-03 -0.077114
# TAGE_ERSTKAUF                    0.000097  0.000071  8.330943e-07 -0.000038
# TAGE_LETZTKAUF                  -0.002213  0.000680  8.255336e-06 -0.003558
# TAGE_ERST_ZWEIT_KAUF            -0.000224  0.000148  1.386698e-06 -0.000524
# TAGE_LETZT_VORLETZT_KAUF        -0.000571  0.000457  4.710122e-06 -0.001456
#
#                                  hpd_97.5         n_eff      Rhat
# Intercept                       -2.156774   7995.921929  0.999913
# EINWOHNERKLASSE_WOHNORT[T.1000]  0.077053  12076.634142  0.999877
# EINWOHNERKLASSE_WOHNORT[T.2000]  0.280052  11500.018570  0.999891
# EINWOHNERKLASSE_WOHNORT[T.250]   0.194320  12316.412090  0.999949
# EINWOHNERKLASSE_WOHNORT[T.500]   0.074083  13552.549772  0.999991
# KUNDENALTER                      0.007727   8752.439211  0.999902
# ANZ_CS_KONTAKTE                  0.017685  11227.606964  0.999884
# ANZ_KINDER                       0.006838  10436.910147  0.999907
# ANZ_AUFTRAEGE                   -0.003511   5088.968150  0.999900
# ANZ_AUFTRAEGE_0_TO_30            0.271511   8028.632052  0.999894
# ANZ_AUFTRAEGE_30_TO_90           0.268678   9093.078080  0.999967
# ANZ_AUFTRAEGE_90_TO_180          0.232542   8913.005167  0.999891
# ANZ_AUFTRAEGE_180_TO_360         0.145901   8108.816870  1.000176
# ANZ_AUFTRAEGE_360_TO_720         0.093733   6449.760704  1.000082
# ANZ_RETOUREN                     0.040280   5489.133344  0.999985
# ANZ_RETOUREN_0_TO_30             0.088274  10215.095205  0.999996
# ANZ_RETOUREN_30_TO_90            0.163941   9491.323439  0.999930
# ANZ_RETOUREN_90_TO_180           0.099984   9805.532654  1.000024
# ANZ_RETOUREN_180_TO_360          0.140513   7914.543636  0.999931
# ANZ_RETOUREN_360_TO_720          0.054929   6975.209884  0.999903
# SUM_LIEFERMENGE_AUFTRAEGE        0.007197   8066.904928  1.000393
# SUM_LIEFERMENGE_RETOUREN         0.102122   8248.927439  0.999978
# ANZ_POSITIONEN_AUFTRAG           0.008267   8262.643842  1.000147
# ANZ_POSITIONEN_RETOUREN          0.026133   8250.684525  0.999973
# ANZ_AUFTRAEGE_GSCHEIN            0.069158   6434.941981  0.999879
# SUM_RABATT_GSCHEIN               0.012363   6101.679681  0.999875
# ANZ_AUFTRAEGE_NL                 0.041695   9434.000848  0.999917
# ANZ_NL_ERHALTEN_0_TO_30          0.013748  10543.234188  0.999920
# ANZ_NL_GEOEFFNET_0_TO_30         0.096024  10327.829183  0.999957
# ANZ_AUFTRAEGE_NL_0_TO_30         0.486419  11916.999568  0.999934
# TAGE_ERSTKAUF                    0.000237   7281.314244  1.000002
# TAGE_LETZTKAUF                  -0.000910   8419.026940  0.999878
# TAGE_ERST_ZWEIT_KAUF             0.000056   8854.832158  0.999966
# TAGE_LETZT_VORLETZT_KAUF         0.000306  10473.886736  1.000079

# %%
pm.traceplot(trace_1[2000: ]);

# %% [markdown]
# posterior predictive check:

# %%
ppc_1 = pm.sample_posterior_predictive(trace_1[2000: ], samples = 2000, model = model_1)
# Out:
# 100%|██████████| 2000/2000 [00:06<00:00, 318.26it/s]

# %%
pred = np.mean(ppc_1['y'], axis=0).round(0)
#pred

# %%
#scikit's confusion matrix is ugly, use pandas
pd.crosstab(train['KAUF_NACH_FLYER'], pred)
# Out:
# col_0             0.0  1.0
# KAUF_NACH_FLYER
# 0                5904   51
# 1                 644   68

# %% [markdown]
# try LASSO as well, shrinkage to zero

# %%
with pm.Model() as model_2:
    # default priors: normally distributed, mimics ridge regression
    priors = {#"Intercept": pm.Normal.dist(mu=0, sd=100),
          "Regressor": pm.Laplace.dist(mu=0, b = 1 / np.sqrt(2))}
    
    # b=1/sqrt(2)
    
    pm.glm.GLM.from_formula('KAUF_NACH_FLYER ~ EINWOHNERKLASSE_WOHNORT + KUNDENALTER + ANZ_CS_KONTAKTE + ANZ_KINDER + ANZ_AUFTRAEGE + ANZ_AUFTRAEGE_0_TO_30 + ANZ_AUFTRAEGE_30_TO_90 + \
                            ANZ_AUFTRAEGE_90_TO_180 + ANZ_AUFTRAEGE_180_TO_360 + ANZ_AUFTRAEGE_360_TO_720 + ANZ_RETOUREN + ANZ_RETOUREN_0_TO_30 + ANZ_RETOUREN_30_TO_90 + \
                            ANZ_RETOUREN_90_TO_180 + ANZ_RETOUREN_180_TO_360 + ANZ_RETOUREN_360_TO_720 + SUM_LIEFERMENGE_AUFTRAEGE + SUM_LIEFERMENGE_RETOUREN + ANZ_POSITIONEN_AUFTRAG + \
                            ANZ_POSITIONEN_RETOUREN + ANZ_AUFTRAEGE_GSCHEIN + SUM_RABATT_GSCHEIN + ANZ_AUFTRAEGE_NL + ANZ_NL_ERHALTEN_0_TO_30 + ANZ_NL_GEOEFFNET_0_TO_30 + \
                            ANZ_AUFTRAEGE_NL_0_TO_30 + TAGE_ERSTKAUF + TAGE_LETZTKAUF + TAGE_ERST_ZWEIT_KAUF + TAGE_LETZT_VORLETZT_KAUF', train, family=pm.glm.families.Binomial())
    
    #start_MAP = pm.find_MAP(fmin=optimize.fmin_powell)
    
    ## Sample using NUTS
    trace_2 = pm.sample(6000, step=pm.NUTS())
# Out:
# Sequential sampling (2 chains in 1 job)
# NUTS: [TAGE_LETZT_VORLETZT_KAUF, TAGE_ERST_ZWEIT_KAUF, TAGE_LETZTKAUF, TAGE_ERSTKAUF, ANZ_AUFTRAEGE_NL_0_TO_30, ANZ_NL_GEOEFFNET_0_TO_30, ANZ_NL_ERHALTEN_0_TO_30, ANZ_AUFTRAEGE_NL, SUM_RABATT_GSCHEIN, ANZ_AUFTRAEGE_GSCHEIN, ANZ_POSITIONEN_RETOUREN, ANZ_POSITIONEN_AUFTRAG, SUM_LIEFERMENGE_RETOUREN, SUM_LIEFERMENGE_AUFTRAEGE, ANZ_RETOUREN_360_TO_720, ANZ_RETOUREN_180_TO_360, ANZ_RETOUREN_90_TO_180, ANZ_RETOUREN_30_TO_90, ANZ_RETOUREN_0_TO_30, ANZ_RETOUREN, ANZ_AUFTRAEGE_360_TO_720, ANZ_AUFTRAEGE_180_TO_360, ANZ_AUFTRAEGE_90_TO_180, ANZ_AUFTRAEGE_30_TO_90, ANZ_AUFTRAEGE_0_TO_30, ANZ_AUFTRAEGE, ANZ_KINDER, ANZ_CS_KONTAKTE, KUNDENALTER, EINWOHNERKLASSE_WOHNORT[T.500], EINWOHNERKLASSE_WOHNORT[T.250], EINWOHNERKLASSE_WOHNORT[T.2000], EINWOHNERKLASSE_WOHNORT[T.1000], Intercept]
# 100%|██████████| 6500/6500 [39:25<00:00,  3.32it/s]
# 100%|██████████| 6500/6500 [36:15<00:00,  2.83it/s]

# %%
pm.summary(trace_2[2000: ])
# Out:
#                                      mean        sd      mc_error   hpd_2.5  \
# Intercept                       -2.670682  0.256226  3.299878e-03 -3.159226
# EINWOHNERKLASSE_WOHNORT[T.1000] -0.451869  0.283110  2.899055e-03 -1.016584
# EINWOHNERKLASSE_WOHNORT[T.2000] -0.112160  0.201856  1.900333e-03 -0.517709
# EINWOHNERKLASSE_WOHNORT[T.250]  -0.252054  0.234575  2.679211e-03 -0.727951
# EINWOHNERKLASSE_WOHNORT[T.500]  -0.292500  0.186616  1.733523e-03 -0.658215
# KUNDENALTER                     -0.004704  0.006286  7.168558e-05 -0.016995
# ANZ_CS_KONTAKTE                 -0.035836  0.027532  2.673190e-04 -0.092333
# ANZ_KINDER                      -0.098548  0.053006  5.408086e-04 -0.198857
# ANZ_AUFTRAEGE                   -0.021799  0.009202  1.400446e-04 -0.039815
# ANZ_AUFTRAEGE_0_TO_30            0.153900  0.058643  6.965069e-04  0.035362
# ANZ_AUFTRAEGE_30_TO_90           0.167747  0.049847  5.388535e-04  0.068782
# ANZ_AUFTRAEGE_90_TO_180          0.145322  0.043004  4.874013e-04  0.062520
# ANZ_AUFTRAEGE_180_TO_360         0.097040  0.027018  2.995441e-04  0.043299
# ANZ_AUFTRAEGE_360_TO_720         0.053317  0.020819  2.808050e-04  0.013333
# ANZ_RETOUREN                     0.009659  0.015498  2.138178e-04 -0.019543
# ANZ_RETOUREN_0_TO_30            -0.066133  0.081426  8.183115e-04 -0.228131
# ANZ_RETOUREN_30_TO_90            0.019942  0.070276  7.345515e-04 -0.118228
# ANZ_RETOUREN_90_TO_180          -0.016960  0.059973  6.419306e-04 -0.136313
# ANZ_RETOUREN_180_TO_360          0.064899  0.039630  4.279074e-04 -0.013194
# ANZ_RETOUREN_360_TO_720         -0.008508  0.032526  3.926587e-04 -0.068502
# SUM_LIEFERMENGE_AUFTRAEGE        0.001396  0.002975  4.712273e-05 -0.004345
# SUM_LIEFERMENGE_RETOUREN         0.037149  0.032859  4.904537e-04 -0.025337
# ANZ_POSITIONEN_AUFTRAG           0.001446  0.003340  5.294423e-05 -0.004955
# ANZ_POSITIONEN_RETOUREN         -0.042067  0.033159  4.934291e-04 -0.107894
# ANZ_AUFTRAEGE_GSCHEIN           -0.014267  0.044201  4.578977e-04 -0.102149
# SUM_RABATT_GSCHEIN               0.002344  0.005359  5.901572e-05 -0.008181
# ANZ_AUFTRAEGE_NL                 0.020560  0.010620  1.374581e-04 -0.000185
# ANZ_NL_ERHALTEN_0_TO_30         -0.003471  0.009268  8.315824e-05 -0.021005
# ANZ_NL_GEOEFFNET_0_TO_30         0.054652  0.020916  1.870242e-04  0.012313
# ANZ_AUFTRAEGE_NL_0_TO_30         0.216197  0.139730  1.657476e-03 -0.074448
# TAGE_ERSTKAUF                    0.000097  0.000073  8.077373e-07 -0.000048
# TAGE_LETZTKAUF                  -0.002207  0.000672  6.882470e-06 -0.003471
# TAGE_ERST_ZWEIT_KAUF            -0.000224  0.000149  1.584751e-06 -0.000520
# TAGE_LETZT_VORLETZT_KAUF        -0.000557  0.000440  4.919733e-06 -0.001398
#
#                                  hpd_97.5         n_eff      Rhat
# Intercept                       -2.165495   5998.974399  0.999878
# EINWOHNERKLASSE_WOHNORT[T.1000]  0.078310  10577.367390  0.999911
# EINWOHNERKLASSE_WOHNORT[T.2000]  0.268671   9748.111182  0.999893
# EINWOHNERKLASSE_WOHNORT[T.250]   0.192457   8395.168402  0.999876
# EINWOHNERKLASSE_WOHNORT[T.500]   0.074348  10710.523510  0.999904
# KUNDENALTER                      0.007461   6774.637757  0.999875
# ANZ_CS_KONTAKTE                  0.015088   9583.343361  0.999886
# ANZ_KINDER                       0.007712   9079.751686  0.999970
# ANZ_AUFTRAEGE                   -0.004240   4999.456230  0.999881
# ANZ_AUFTRAEGE_0_TO_30            0.265466   7316.967571  0.999875
# ANZ_AUFTRAEGE_30_TO_90           0.264040   7797.237443  0.999925
# ANZ_AUFTRAEGE_90_TO_180          0.228697   8771.990561  0.999885
# ANZ_AUFTRAEGE_180_TO_360         0.148470   7427.797534  0.999970
# ANZ_AUFTRAEGE_360_TO_720         0.095006   5431.151366  1.000002
# ANZ_RETOUREN                     0.040529   5199.837705  0.999965
# ANZ_RETOUREN_0_TO_30             0.094850   8964.196189  0.999876
# ANZ_RETOUREN_30_TO_90            0.154361   7802.449072  0.999878
# ANZ_RETOUREN_90_TO_180           0.101743   8954.019556  0.999926
# ANZ_RETOUREN_180_TO_360          0.140871   7985.902365  0.999885
# ANZ_RETOUREN_360_TO_720          0.058180   5739.972441  1.000216
# SUM_LIEFERMENGE_AUFTRAEGE        0.007675   4289.999294  0.999878
# SUM_LIEFERMENGE_RETOUREN         0.103117   4586.963704  1.000015
# ANZ_POSITIONEN_AUFTRAG           0.008219   3978.584613  0.999875
# ANZ_POSITIONEN_RETOUREN          0.021741   4555.224046  1.000021
# ANZ_AUFTRAEGE_GSCHEIN            0.071448   6980.404341  1.000127
# SUM_RABATT_GSCHEIN               0.012681   7022.641790  1.000189
# ANZ_AUFTRAEGE_NL                 0.041504   8213.404758  0.999918
# ANZ_NL_ERHALTEN_0_TO_30          0.014721   8263.866210  0.999957
# ANZ_NL_GEOEFFNET_0_TO_30         0.093722  10015.336654  0.999875
# ANZ_AUFTRAEGE_NL_0_TO_30         0.473153   8919.909178  1.000417
# TAGE_ERSTKAUF                    0.000236   6961.579547  0.999917
# TAGE_LETZTKAUF                  -0.000879   7917.497760  0.999875
# TAGE_ERST_ZWEIT_KAUF             0.000060   8205.756415  0.999941
# TAGE_LETZT_VORLETZT_KAUF         0.000302   9834.444700  0.999969

# %%
pm.traceplot(trace_2[2000: ]);

# %%
ppc_2 = pm.sample_posterior_predictive(trace_2[2000: ], samples = 2000, model = model_2)
# Out:
# 100%|██████████| 2000/2000 [00:05<00:00, 340.77it/s]

# %%
pred2 = np.mean(ppc_2['y'], axis=0).round(0)
#pred

# %%
pd.crosstab(train['KAUF_NACH_FLYER'], pred2)
# Out:
# col_0             0.0  1.0
# KAUF_NACH_FLYER
# 0                5904   51
# 1                 645   67
